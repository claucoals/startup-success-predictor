# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Requirement already satisfied: mlxtend==0.23.3 in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 2)) (0.23.3)
# Requirement already satisfied: imblearn==0.0 in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 3)) (0.0)
# Requirement already satisfied: missingno==0.5.2 in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 4)) (0.5.2)
# Requirement already satisfied: xgboost==2.1.4 in /root/venv/lib/python3.9/site-packages (from -r ./requirements.txt (line 5)) (2.1.4)
# Requirement already satisfied: pandas>=0.24.2 in /toolkit-cache/0.2.7/python3.9/kernel-libs/lib/python3.9/site-packages (from mlxtend==0.23.3->-r ./requirements.txt (line 2)) (1.5.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in /root/venv/lib/python3.9/site-packages (from mlxtend==0.23.3->-r ./requirements.txt (line 2)) (1.6.1)
# Requirement already satisfied: numpy>=1.16.2 in /toolkit-cache/0.2.7/python3.9/kernel-libs/lib/python3.9/site-packages (from mlxtend==0.23.3->-r ./requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: joblib>=0.13.2 in /root/venv/lib/python3.9/site-packages (from mlxtend==0.23.3->-r ./requirements.txt (line 2)) (1.4.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /root/venv/lib/python3.9/site-packages (from mlxtend==0.23.3->-r ./requirements.txt (line 2)) (3.9.4)
# Requirement already satisfied: scipy>=1.2.1 in /root/venv/lib/python3.9/site-packages (from mlxtend==0.23.3->-r ./requirements.txt (line 2)) (1.13.1)
# Requirement already satisfied: imbalanced-learn in /root/venv/lib/python3.9/site-packages (from imblearn==0.0->-r ./requirements.txt (line 3)) (0.12.4)
# Requirement already satisfied: seaborn in /root/venv/lib/python3.9/site-packages (from missingno==0.5.2->-r ./requirements.txt (line 4)) (0.13.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /root/venv/lib/python3.9/site-packages (from xgboost==2.1.4->-r ./requirements.txt (line 5)) (2.25.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /root/venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3->-r ./requirements.txt (line 2)) (1.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /toolkit-cache/0.2.7/python3.9/kernel-libs/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3->-r ./requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3->-r ./requirements.txt (line 2)) (4.56.0)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3->-r ./requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: pillow>=8 in /root/venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3->-r ./requirements.txt (line 2)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /root/venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3->-r ./requirements.txt (line 2)) (3.2.1)
# Requirement already satisfied: cycler>=0.10 in /root/venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3->-r ./requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in /toolkit-cache/0.2.7/python3.9/kernel-libs/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3->-r ./requirements.txt (line 2)) (24.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /root/venv/lib/python3.9/site-packages (from matplotlib>=3.0.0->mlxtend==0.23.3->-r ./requirements.txt (line 2)) (6.5.2)
# Requirement already satisfied: pytz>=2020.1 in /toolkit-cache/0.2.7/python3.9/kernel-libs/lib/python3.9/site-packages (from pandas>=0.24.2->mlxtend==0.23.3->-r ./requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /root/venv/lib/python3.9/site-packages (from scikit-learn>=1.3.1->mlxtend==0.23.3->-r ./requirements.txt (line 2)) (3.5.0)
# Requirement already satisfied: zipp>=3.1.0 in /root/venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0.0->mlxtend==0.23.3->-r ./requirements.txt (line 2)) (3.21.0)
# Requirement already satisfied: six>=1.5 in /toolkit-cache/0.2.7/python3.9/kernel-libs/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend==0.23.3->-r ./requirements.txt (line 2)) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=cb34235f-872b-4701-bb38-af02af0a7bfd' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
